# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("house_prices.csv")

# %%
df.head()
df.shape
# Out:
# (187531, 21)

# %%
df.columns
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Index              187531 non-null  int64
#  1   Title              187531 non-null  str
#  2   Description        184508 non-null  str
#  3   Amount(in rupees)  187531 non-null  str
#  4   Price (in rupees)  169866 non-null  float64
#  5   location           187531 non-null  str
#  6   Carpet Area        106858 non-null  str
#  7   Status             186916 non-null  str
#  8   Floor              180454 non-null  str
#  9   Transaction        187448 non-null  str
#  10  Furnishing         184634 non-null  str
#  11  facing             117298 non-null  str
#  12  overlooking        106095 non-null  str
#  13  Society            77853 non-null   str
#  14  Bathroom           186703 non-null  str
#  15  Balcony            138596 non-null  str
# ...

# %%
df[["Amount(in rupees)", "Price (in rupees)"]].head(10)
df[["Amount(in rupees)", "Price (in rupees)"]].describe()
# Out:
#   Amount(in rupees)  Price (in rupees)
# 0           42 Lac              6000.0
# 1           98 Lac             13799.0
# 2          1.40 Cr             17500.0
# 3           25 Lac                 NaN
# 4          1.60 Cr             18824.0
# 5           45 Lac              6618.0
# 6         16.5 Lac              2538.0
# 7           60 Lac             10435.0
# 8           60 Lac             10000.0
# 9          1.60 Cr             11150.0

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Index                  0.000000
# Title                  0.000000
# Description            1.612000
# Amount(in rupees)      0.000000
# Price (in rupees)      9.419776
# location               0.000000
# Carpet Area           43.018488
# Status                 0.327946
# Floor                  3.773776
# Transaction            0.044259
# Furnishing             1.544811
# facing                37.451408
# overlooking           43.425354
# Society               58.485264
# Bathroom               0.441527
# Balcony               26.094352
# Car Parking           55.114621
# Ownership             34.936624
# Super Area            57.422506
# Dimensions           100.000000
# Plot Area            100.000000
# dtype: float64

# %%
df["Status"].value_counts()
df["Furnishing"].value_counts()
df["Transaction"].value_counts()
df["Ownership"].value_counts()
# Out:
# Furnishing
# Semi-Furnished    88318
# Unfurnished       76154
# Furnished         20162
# Name: count, dtype: int64

# %%
df["location"].value_counts().head(10)
df["location"].value_counts().tail(10)

# %%
df["Floor"].value_counts().head(20)
df["Bathroom"].value_counts()
df["Balcony"].value_counts()
df["Balcony"].value_counts()
df["Car Parking"].value_counts()
# Out:
# Car Parking
# 1 Covered      38754
# 1 Covered,     16991
# 2 Covered      10691
# 1 Open          7873
# 2 Covered,      3978
#                ...
# 104 Covered        1
# 205 Covered        1
# 11 Covered,        1
# 403 Covered        1
# 702 Open           1
# Name: count, Length: 229, dtype: int64

# %%
df["Car Parking"].dropna().head(20).tolist()
# Out:
# ['1 Open',
#  '1 Covered',
#  '1 Covered',
#  '1 Covered',
#  '1 Open',
#  '2 Covered',
#  '1 Covered',
#  '66 Covered',
#  '1 Open',
#  '1 Open',
#  '1 Covered',
#  '1 Covered',
#  '1 Covered',
#  '1 Open',
#  '2 Covered',
#  '1 Covered',
#  '1 Covered',
#  '1 Covered',
#  '1 Covered',
#  '1 Covered']

# %%
df["Carpet Area"].dropna().head(20).tolist()
df["Super Area"].dropna().head(20).tolist()
# Out:
# ['680 sqft',
#  '575 sqft',
#  '600 sqft',
#  '1165 sqft',
#  '844 sqft',
#  '650 sqft',
#  '540 sqft',
#  '520 sqft',
#  '525 sqft',
#  '580 sqft',
#  '630 sqft',
#  '690 sqft',
#  '750 sqft',
#  '550 sqft',
#  '482 sqft',
#  '1100 sqft',
#  '770 sqft',
#  '530 sqft',
#  '481 sqft',
#  '381 sqft']

# %%
df["Amount(in rupees)"].str.extract(r'([A-Za-z]+)')[0].value_counts()
# Out:
# 0
# Lac     112568
# Cr       65279
# Call      9684
# Name: count, dtype: int64

# %%
df["Amount(in rupees)"].value_counts().head(20)
# Out:
# Amount(in rupees)
# Call for Price    9684
# 85 Lac            5264
# 65 Lac            4229
# 60 Lac            3869
# 70 Lac            3801
# 35 Lac            3369
# 75 Lac            3144
# 90 Lac            3143
# 40 Lac            3098
# 50 Lac            3006
# 1.75 Cr           2879
# 30 Lac            2790
# 25 Lac            2771
# 51 Lac            2682
# 45 Lac            2665
# 1.30 Cr           2561
# 22 Lac            2537
# 2.35 Cr           2361
# 23 Lac            2312
# 88 Lac            2310
# Name: count, dtype: int64
